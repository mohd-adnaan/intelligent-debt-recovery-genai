# %%
import pandas as pd
import numpy as np
import re
import pickle
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

# %%
# Step 1: Load the Dataset
file_path = "/Users/mohammadadnaan/Downloads/Prodigal_Tech/intelligent-debt-recovery-genai/src/ml_models/privacy_compliance_detection/conversations_with_labels.xlsx"
df = pd.read_excel(file_path)

# Display the first few rows of the dataset
print(df.head())
# Out:
#                                 Call ID  \
# 0  2db2965e-54fa-41fa-823b-ed79b943f0b1
# 1  8a9655a7-be88-4921-b0ad-04aa1b9953d1
# 2  19169ec6-213f-48e9-8ec2-c24ee2e6eb20
# 3  c86714f0-3aeb-4628-8cfa-ee0a46839508
# 4  0c8297aa-ced1-414e-a175-bf29a9763d30
#
#                                                 Text  Label  \
# 0  Hello, this is Emma from XYZ Collections, how ...      0
# 1  Hello, this is Mark from XYZ Collections. How ...      0
# 2  Hello, this is Mark calling from XYZ Collectio...      0
# 3  Hello, this is Mark calling from XYZ Collectio...      0
# 4  Hello, this is Mike from XYZ Collections. Am I...      0
#
#    Double Verification
# 0                    0
# 1                    1
# 2                    0
# 3                    1
# 4                    1

# %%
# Step 2: Preprocess the Text Data
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    
    # Remove special characters and numbers
    text = re.sub(r"[^a-zA-Z\s]", "", text)
    
    # Lemmatization (using simple rule-based approach)
    lemmatized_text = []
    for word in text.split():
        if word.endswith('ing'):
            word = word[:-3]  # Remove 'ing'
        elif word.endswith('ed'):
            word = word[:-2]  # Remove 'ed'
        elif word.endswith('s'):
            word = word[:-1]  # Remove 's'
        lemmatized_text.append(word)
    text = " ".join(lemmatized_text)
    
    # Remove stop words (using a custom list)
    stop_words = set(["the", "and", "is", "in", "it", "to", "of", "for", "with", "on", "at", "by", "this", "that", "are", "as", "be", "was", "were", "you", "your", "we", "our"])
    text = " ".join([word for word in text.split() if word not in stop_words])
    
    return text

# Apply preprocessing to the text column
df["Processed_Text"] = df["Text"].apply(preprocess_text)

# %%
# Step 3: Tokenization and Padding
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(df["Processed_Text"])

with open('/Users/mohammadadnaan/Downloads/Prodigal_Tech/intelligent-debt-recovery-genai/src/ml_models/privacy_compliance_detection/tokenizer.pkl', 'wb') as f:
    pickle.dump(tokenizer, f)  # Save FIRST

# Convert text to sequences
sequences = tokenizer.texts_to_sequences(df["Processed_Text"])
max_len = 100
padded_sequences = pad_sequences(sequences, maxlen=max_len, padding="post")

# %%
# Step 4: Prepare Labels
labels = df["Label"].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, labels, test_size=0.2, random_state=42)

# %%
# Step 5: Build the LSTM Model
embedding_dim = 100  # Dimension of word embeddings
vocab_size = len(tokenizer.word_index) + 1  # Vocabulary size

model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_shape=(max_len,)),  # Add input_shape
    LSTM(128, dropout=0.2, recurrent_dropout=0.2),
    Dense(64, activation="relu"),
    Dropout(0.5),
    Dense(1, activation="sigmoid")  # Binary classification
])

# Compile the model
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# Display the model summary
model.summary()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 100, 100)       │        94,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 128)            │       117,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 219,569 (857.69 KB)
#  Trainable params: 219,569 (857.69 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Step 6: Train the Model
history = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.7047 - loss: 0.6769 - val_accuracy: 0.9500 - val_loss: 0.5896
# Epoch 2/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8753 - loss: 0.5318 - val_accuracy: 0.9500 - val_loss: 0.1840
# Epoch 3/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8745 - loss: 0.3978 - val_accuracy: 0.9500 - val_loss: 0.2707
# Epoch 4/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8506 - loss: 0.3636 - val_accuracy: 0.9500 - val_loss: 0.3044
# Epoch 5/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8432 - loss: 0.3824 - val_accuracy: 0.9500 - val_loss: 0.2259
# Epoch 6/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8441 - loss: 0.3278 - val_accuracy: 0.9500 - val_loss: 0.1610
# Epoch 7/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9104 - loss: 0.2388 - val_accuracy: 0.9500 - val_loss: 0.1618
# Epoch 8/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8588 - loss: 0.2737 - val_accuracy: 0.9500 - val_loss: 0.2302
# Epoch 9/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9205 - loss: 0.2520 - val_accuracy: 0.9500 - val_loss: 0.2001
# Epoch 10/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.8741 - loss: 0.2614 - val_accuracy: 0.9500 - val_loss: 0.1435
# Epoch 11/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8835 - loss: 0.2037 - val_accuracy: 0.9250 - val_loss: 0.1241
# Epoch 12/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9597 - loss: 0.0987 - val_accuracy: 0.9000 - val_loss: 0.1495
# Epoch 13/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9876 - loss: 0.0869 - val_accuracy: 0.9000 - val_loss: 0.1757
# Epoch 14/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9772 - loss: 0.0641 - val_accuracy: 0.9500 - val_loss: 0.2640
# Epoch 15/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9669 - loss: 0.3851 - val_accuracy: 0.9500 - val_loss: 0.1856
# Epoch 16/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9850 - loss: 0.0648 - val_accuracy: 0.8250 - val_loss: 0.3723
# Epoch 17/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9554 - loss: 0.1450 - val_accuracy: 0.8250 - val_loss: 0.3606
# Epoch 18/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9923 - loss: 0.0706 - val_accuracy: 0.9250 - val_loss: 0.2180
# Epoch 19/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9881 - loss: 0.0564 - val_accuracy: 0.9500 - val_loss: 0.2201
# Epoch 20/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9690 - loss: 0.0956 - val_accuracy: 0.9500 - val_loss: 0.1273
# Epoch 21/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9643 - loss: 0.0993 - val_accuracy: 0.9250 - val_loss: 0.1464
# Epoch 22/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9690 - loss: 0.0618 - val_accuracy: 0.9250 - val_loss: 0.1603
# Epoch 23/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9889 - loss: 0.0555 - val_accuracy: 0.9500 - val_loss: 0.1662
# Epoch 24/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9949 - loss: 0.0312 - val_accuracy: 0.9500 - val_loss: 0.1499
# Epoch 25/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.9500 - val_loss: 0.1361
# Epoch 26/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9500 - val_loss: 0.1843
# Epoch 27/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9500 - val_loss: 0.1729
# Epoch 28/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.8750 - val_loss: 0.3015
# Epoch 29/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.8750 - val_loss: 0.3254
# Epoch 30/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.8750 - val_loss: 0.2956
# Epoch 31/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.8750 - val_loss: 0.2479
# Epoch 32/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9250 - val_loss: 0.1934
# Epoch 33/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9500 - val_loss: 0.1657
# Epoch 34/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9500 - val_loss: 0.1800
# Epoch 35/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9500 - val_loss: 0.1972
# Epoch 36/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 6.9109e-04 - val_accuracy: 0.9500 - val_loss: 0.2107
# Epoch 37/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9500 - val_loss: 0.2214
# Epoch 38/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 9.6958e-04 - val_accuracy: 0.9500 - val_loss: 0.2297
# Epoch 39/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9500 - val_loss: 0.2267
# Epoch 40/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9000 - val_loss: 0.3972
# Epoch 41/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0163 - val_accuracy: 0.8750 - val_loss: 0.4948
# Epoch 42/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9966 - loss: 0.0396 - val_accuracy: 0.9000 - val_loss: 0.3557
# Epoch 43/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9979 - loss: 0.0107 - val_accuracy: 0.9750 - val_loss: 0.2858
# Epoch 44/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.9500 - val_loss: 0.2941
# Epoch 45/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9250 - val_loss: 0.3393
# Epoch 46/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.9250 - val_loss: 0.4657
# Epoch 47/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9928 - loss: 0.0161 - val_accuracy: 0.9250 - val_loss: 0.3528
# Epoch 48/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9772 - loss: 0.0491 - val_accuracy: 0.9250 - val_loss: 0.3501
# Epoch 49/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 0.9250 - val_loss: 0.2905
# Epoch 50/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.9750 - val_loss: 0.2591
# Epoch 51/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9500 - val_loss: 0.2970
# Epoch 52/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9250 - val_loss: 0.3511
# Epoch 53/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9250 - val_loss: 0.3925
# Epoch 54/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 5.3756e-04 - val_accuracy: 0.9000 - val_loss: 0.4178
# Epoch 55/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 9.0590e-04 - val_accuracy: 0.9000 - val_loss: 0.4222
# Epoch 56/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 5.8514e-04 - val_accuracy: 0.9250 - val_loss: 0.4058
# Epoch 57/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 6.4526e-04 - val_accuracy: 0.9250 - val_loss: 0.3992
# Epoch 58/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 4.0442e-04 - val_accuracy: 0.9250 - val_loss: 0.3968
# Epoch 59/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 8.4973e-04 - val_accuracy: 0.9250 - val_loss: 0.3966
# Epoch 60/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9500 - val_loss: 0.3877
# Epoch 61/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 2.1828e-04 - val_accuracy: 0.9500 - val_loss: 0.3845
# Epoch 62/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 4.7275e-04 - val_accuracy: 0.9500 - val_loss: 0.3839
# Epoch 63/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 3.7665e-04 - val_accuracy: 0.9500 - val_loss: 0.3853
# Epoch 64/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9500 - val_loss: 0.3897
# Epoch 65/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 9.8538e-05 - val_accuracy: 0.9500 - val_loss: 0.3929
# Epoch 66/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 8.7505e-04 - val_accuracy: 0.9500 - val_loss: 0.3970
# Epoch 67/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9500 - val_loss: 0.3941
# Epoch 68/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 4.3880e-04 - val_accuracy: 0.9500 - val_loss: 0.3935
# Epoch 69/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 3.1548e-04 - val_accuracy: 0.9500 - val_loss: 0.3945
# Epoch 70/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 7.6162e-04 - val_accuracy: 0.9500 - val_loss: 0.3816
# Epoch 71/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9500 - val_loss: 0.3273
# Epoch 72/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 5.2405e-04 - val_accuracy: 0.9250 - val_loss: 0.3630
# Epoch 73/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9979 - loss: 0.0346 - val_accuracy: 0.9250 - val_loss: 0.3662
# Epoch 74/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 3.5737e-04 - val_accuracy: 0.9250 - val_loss: 0.3104
# Epoch 75/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 8.1004e-04 - val_accuracy: 0.9500 - val_loss: 0.2938
# Epoch 76/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9500 - val_loss: 0.2942
# Epoch 77/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9500 - val_loss: 0.2938
# Epoch 78/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 8.8734e-04 - val_accuracy: 0.9500 - val_loss: 0.2910
# Epoch 79/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9500 - val_loss: 0.2882
# Epoch 80/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9500 - val_loss: 0.2869
# Epoch 81/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9500 - val_loss: 0.2872
# Epoch 82/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9500 - val_loss: 0.2867
# Epoch 83/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 9.4827e-04 - val_accuracy: 0.9500 - val_loss: 0.2862
# Epoch 84/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 6.4338e-04 - val_accuracy: 0.9500 - val_loss: 0.2872
# Epoch 85/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 3.5545e-04 - val_accuracy: 0.9500 - val_loss: 0.2886
# Epoch 86/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9500 - val_loss: 0.2910
# Epoch 87/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 3.2007e-04 - val_accuracy: 0.9500 - val_loss: 0.2934
# Epoch 88/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 2.4450e-04 - val_accuracy: 0.9500 - val_loss: 0.2956
# Epoch 89/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 5.2034e-04 - val_accuracy: 0.9500 - val_loss: 0.2989
# Epoch 90/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 3.7224e-04 - val_accuracy: 0.9500 - val_loss: 0.3031
# Epoch 91/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 2.5302e-04 - val_accuracy: 0.9500 - val_loss: 0.3065
# Epoch 92/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 2.8851e-04 - val_accuracy: 0.9500 - val_loss: 0.3091
# Epoch 93/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 2.2443e-04 - val_accuracy: 0.9500 - val_loss: 0.3120
# Epoch 94/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 2.5216e-04 - val_accuracy: 0.9500 - val_loss: 0.3158
# Epoch 95/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 4.6850e-04 - val_accuracy: 0.9500 - val_loss: 0.3211
# Epoch 96/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 3.3389e-04 - val_accuracy: 0.9500 - val_loss: 0.3271
# Epoch 97/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.5521e-04 - val_accuracy: 0.9500 - val_loss: 0.3317
# Epoch 98/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 4.0805e-04 - val_accuracy: 0.9500 - val_loss: 0.3368
# Epoch 99/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 6.2062e-04 - val_accuracy: 0.9500 - val_loss: 0.3430
# Epoch 100/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 2.0155e-04 - val_accuracy: 0.9500 - val_loss: 0.3478
# Epoch 101/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 2.0043e-04 - val_accuracy: 0.9500 - val_loss: 0.3524
# Epoch 102/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9500 - val_loss: 0.3593
# Epoch 103/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 2.4413e-04 - val_accuracy: 0.9500 - val_loss: 0.3649
# Epoch 104/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.9435e-04 - val_accuracy: 0.9500 - val_loss: 0.3697
# Epoch 105/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 2.1327e-04 - val_accuracy: 0.9500 - val_loss: 0.3744
# Epoch 106/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 3.4212e-04 - val_accuracy: 0.9500 - val_loss: 0.3786
# Epoch 107/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 2.5715e-04 - val_accuracy: 0.9500 - val_loss: 0.3820
# Epoch 108/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 2.0976e-04 - val_accuracy: 0.9500 - val_loss: 0.3860
# Epoch 109/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 1.3313e-04 - val_accuracy: 0.9500 - val_loss: 0.3892
# Epoch 110/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 2.3191e-04 - val_accuracy: 0.9500 - val_loss: 0.3924
# Epoch 111/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 3.2516e-04 - val_accuracy: 0.9500 - val_loss: 0.3950
# Epoch 112/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 1.4649e-04 - val_accuracy: 0.9500 - val_loss: 0.3980
# Epoch 113/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.1409e-04 - val_accuracy: 0.9500 - val_loss: 0.4001
# Epoch 114/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 2.3857e-04 - val_accuracy: 0.9500 - val_loss: 0.4023
# Epoch 115/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.1807e-04 - val_accuracy: 0.9500 - val_loss: 0.4047
# Epoch 116/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.1255e-04 - val_accuracy: 0.9500 - val_loss: 0.4068
# Epoch 117/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.8007e-04 - val_accuracy: 0.9500 - val_loss: 0.4084
# Epoch 118/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 7.9598e-05 - val_accuracy: 0.9500 - val_loss: 0.4098
# Epoch 119/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 2.0794e-04 - val_accuracy: 0.9500 - val_loss: 0.4113
# Epoch 120/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 9.6028e-05 - val_accuracy: 0.9500 - val_loss: 0.4127
# Epoch 121/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 8.6599e-05 - val_accuracy: 0.9500 - val_loss: 0.4140
# Epoch 122/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 8.1882e-05 - val_accuracy: 0.9500 - val_loss: 0.4150
# Epoch 123/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 1.1337e-04 - val_accuracy: 0.9500 - val_loss: 0.4161
# Epoch 124/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 1.2213e-04 - val_accuracy: 0.9500 - val_loss: 0.4170
# Epoch 125/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.4452e-04 - val_accuracy: 0.9500 - val_loss: 0.4178
# Epoch 126/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.0316e-04 - val_accuracy: 0.9500 - val_loss: 0.4190
# Epoch 127/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 2.2312e-04 - val_accuracy: 0.9500 - val_loss: 0.4203
# Epoch 128/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 1.2252e-04 - val_accuracy: 0.9500 - val_loss: 0.4221
# Epoch 129/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 6.4925e-05 - val_accuracy: 0.9500 - val_loss: 0.4242
# Epoch 130/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 2.1512e-04 - val_accuracy: 0.9500 - val_loss: 0.4272
# Epoch 131/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 8.6353e-05 - val_accuracy: 0.9500 - val_loss: 0.4296
# Epoch 132/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.4254e-04 - val_accuracy: 0.9500 - val_loss: 0.4314
# Epoch 133/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 2.3004e-04 - val_accuracy: 0.9500 - val_loss: 0.4325
# Epoch 134/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 4.0903e-05 - val_accuracy: 0.9500 - val_loss: 0.4334
# Epoch 135/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 1.0770e-04 - val_accuracy: 0.9500 - val_loss: 0.4346
# Epoch 136/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.3081e-04 - val_accuracy: 0.9500 - val_loss: 0.4370
# Epoch 137/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.5603e-04 - val_accuracy: 0.9500 - val_loss: 0.4398
# Epoch 138/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 4.6082e-05 - val_accuracy: 0.9500 - val_loss: 0.4418
# Epoch 139/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 5.9762e-05 - val_accuracy: 0.9500 - val_loss: 0.4437
# Epoch 140/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 7.8439e-05 - val_accuracy: 0.9500 - val_loss: 0.4456
# Epoch 141/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 1.1747e-04 - val_accuracy: 0.9500 - val_loss: 0.4475
# Epoch 142/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 9.9967e-05 - val_accuracy: 0.9500 - val_loss: 0.4492
# Epoch 143/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 6.4714e-05 - val_accuracy: 0.9500 - val_loss: 0.4507
# Epoch 144/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 4.5464e-05 - val_accuracy: 0.9500 - val_loss: 0.4521
# Epoch 145/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 9.9233e-05 - val_accuracy: 0.9500 - val_loss: 0.4531
# Epoch 146/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 1.0291e-04 - val_accuracy: 0.9500 - val_loss: 0.4545
# Epoch 147/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 6.0355e-05 - val_accuracy: 0.9500 - val_loss: 0.4561
# Epoch 148/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.6248e-04 - val_accuracy: 0.9500 - val_loss: 0.4576
# Epoch 149/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 3.0561e-05 - val_accuracy: 0.9500 - val_loss: 0.4590
# Epoch 150/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 1.6856e-04 - val_accuracy: 0.9500 - val_loss: 0.4612
# Epoch 151/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.0225e-04 - val_accuracy: 0.9500 - val_loss: 0.4636
# Epoch 152/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.8138e-04 - val_accuracy: 0.9500 - val_loss: 0.4665
# Epoch 153/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 5.7431e-05 - val_accuracy: 0.9500 - val_loss: 0.4691
# Epoch 154/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.1054e-04 - val_accuracy: 0.9500 - val_loss: 0.4727
# Epoch 155/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 9.3550e-05 - val_accuracy: 0.9500 - val_loss: 0.4753
# Epoch 156/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 7.4438e-05 - val_accuracy: 0.9500 - val_loss: 0.4776
# Epoch 157/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.3557e-04 - val_accuracy: 0.9500 - val_loss: 0.4793
# Epoch 158/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 5.8780e-05 - val_accuracy: 0.9500 - val_loss: 0.4805
# Epoch 159/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.5476e-04 - val_accuracy: 0.9500 - val_loss: 0.4826
# Epoch 160/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 7.4293e-05 - val_accuracy: 0.9500 - val_loss: 0.4842
# Epoch 161/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 6.6885e-05 - val_accuracy: 0.9500 - val_loss: 0.4855
# Epoch 162/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 6.5687e-05 - val_accuracy: 0.9500 - val_loss: 0.4867
# Epoch 163/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 4.0349e-05 - val_accuracy: 0.9500 - val_loss: 0.4881
# Epoch 164/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 3.7344e-05 - val_accuracy: 0.9500 - val_loss: 0.4896
# Epoch 165/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 3.3893e-05 - val_accuracy: 0.9500 - val_loss: 0.4908
# Epoch 166/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 8.0305e-05 - val_accuracy: 0.9500 - val_loss: 0.4920
# Epoch 167/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 4.6957e-05 - val_accuracy: 0.9500 - val_loss: 0.4933
# Epoch 168/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 2.1783e-05 - val_accuracy: 0.9500 - val_loss: 0.4943
# Epoch 169/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 7.7720e-05 - val_accuracy: 0.9500 - val_loss: 0.4949
# Epoch 170/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 3.3210e-05 - val_accuracy: 0.9500 - val_loss: 0.4954
# Epoch 171/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.0510e-04 - val_accuracy: 0.9500 - val_loss: 0.4967
# Epoch 172/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.9750e-04 - val_accuracy: 0.9500 - val_loss: 0.4958
# Epoch 173/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 4.2072e-05 - val_accuracy: 0.9500 - val_loss: 0.4944
# Epoch 174/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.9400e-04 - val_accuracy: 0.9500 - val_loss: 0.4944
# Epoch 175/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 6.3300e-05 - val_accuracy: 0.9500 - val_loss: 0.4946
# Epoch 176/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 3.1178e-05 - val_accuracy: 0.9500 - val_loss: 0.4949
# Epoch 177/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 4.4145e-05 - val_accuracy: 0.9500 - val_loss: 0.4952
# Epoch 178/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 4.1613e-05 - val_accuracy: 0.9500 - val_loss: 0.4955
# Epoch 179/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 4.4768e-05 - val_accuracy: 0.9500 - val_loss: 0.4962
# Epoch 180/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 3.5951e-05 - val_accuracy: 0.9500 - val_loss: 0.4969
# Epoch 181/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 4.9884e-05 - val_accuracy: 0.9500 - val_loss: 0.4978
# Epoch 182/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 3.9411e-05 - val_accuracy: 0.9500 - val_loss: 0.4986
# Epoch 183/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 6.9826e-05 - val_accuracy: 0.9500 - val_loss: 0.4998
# Epoch 184/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 2.1463e-05 - val_accuracy: 0.9500 - val_loss: 0.5009
# Epoch 185/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 1.7268e-05 - val_accuracy: 0.9500 - val_loss: 0.5016
# Epoch 186/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 4.9935e-05 - val_accuracy: 0.9500 - val_loss: 0.5027
# Epoch 187/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 2.8714e-05 - val_accuracy: 0.9500 - val_loss: 0.5038
# Epoch 188/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 5.2832e-05 - val_accuracy: 0.9500 - val_loss: 0.5046
# Epoch 189/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 2.6268e-04 - val_accuracy: 0.9500 - val_loss: 0.5064
# Epoch 190/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 5.0750e-05 - val_accuracy: 0.9500 - val_loss: 0.5086
# Epoch 191/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.5327e-04 - val_accuracy: 0.9500 - val_loss: 0.5105
# Epoch 192/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 4.6102e-05 - val_accuracy: 0.9500 - val_loss: 0.5120
# Epoch 193/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 3.4143e-05 - val_accuracy: 0.9500 - val_loss: 0.5129
# Epoch 194/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 4.5359e-05 - val_accuracy: 0.9500 - val_loss: 0.5134
# Epoch 195/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 2.3171e-05 - val_accuracy: 0.9500 - val_loss: 0.5138
# Epoch 196/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.7829e-05 - val_accuracy: 0.9500 - val_loss: 0.5143
# Epoch 197/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 3.6999e-05 - val_accuracy: 0.9500 - val_loss: 0.5147
# Epoch 198/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 5.4309e-05 - val_accuracy: 0.9500 - val_loss: 0.5149
# Epoch 199/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 9.6516e-04 - val_accuracy: 0.9500 - val_loss: 0.5167
# Epoch 200/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 3.0086e-05 - val_accuracy: 0.9500 - val_loss: 0.5181

# %%
# Step 7: Evaluate the Model
# Predict on the test set
y_pred = (model.predict(X_test) > 0.5).astype("int32")

# Print classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Print accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93        45
#            1       0.33      0.20      0.25         5
#
#     accuracy                           0.88        50
#    macro avg       0.62      0.58      0.59        50
# weighted avg       0.86      0.88      0.87        50
#
# Accuracy: 88.00%

# %%
# Step 8: Save the Model
model.save("privacy_compliance_lstm_model.keras")
print("Model saved successfully.")
# Out:
# Model saved successfully.

# %%
import numpy as np

# Example message to test
message = ['Your account has been flagged for suspicious activity. Please call us immediately to resolve the issue.']

# Step 1: Tokenize and pad the message
seq = tokenizer.texts_to_sequences(message)  # Convert text to sequence of integers
padded = pad_sequences(seq, maxlen=max_len, dtype='int32', value=0)  # Pad the sequence

# Step 2: Make a prediction with the model
pred = model.predict(padded)  # Get the prediction probability

# Define labels
labels = ['No issue (Label 0)', 'Sensitive info shared without verification (Label 1)']

# Get the predicted class (0 or 1)
predicted_class = int(pred[0][0] > 0.5)  # Threshold at 0.5 for binary classification

# Step 4: Show the predicted class with its probability
print(f"Prediction: {labels[predicted_class]} with probability: {pred[0][0] * 100:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Prediction: No issue (Label 0) with probability: 0.00%

# %%
message = ['Hello, this is Mark from XYZ Collections. How are you today? What the hell do you want? I have told you assholes to leave me alone! I understand that you may be upset. I am calling about your account with ABC Bank. Can I have your account number to assist you? Why the fuck would I give you anything? You are just some low-life calling me! I assure you, I am here to help resolve this matter. Your current balance is $500. How do you prefer to settle this? Settle this? You guys are a bunch of crooks! I do not owe you shit! I understand your frustration. However, it is important for us to discuss this. The account is past due. Fuck you! You think I am gonna pay you just because you say so? I appreciate your honesty. My goal is simply to find a solution. Would you be open to setting up a payment plan? A payment plan? You are dreaming! Not a dime from me! I respect your decision. Just know I am here to assist whenever you are ready to discuss options. Yeah, whatever. Just get the hell off my phone! Thank you for your time. Have a good day.']

# Step 1: Tokenize and pad the message
seq = tokenizer.texts_to_sequences(message)  # Convert text to sequence of integers
padded = pad_sequences(seq, maxlen=max_len, dtype='int32', value=0)  # Pad the sequence

# Step 2: Make a prediction with the model
pred = model.predict(padded)  # Get the prediction probability

# Define labels
labels = ['No issue (Label 0)', 'Sensitive info shared without verification (Label 1)']

# Get the predicted class (0 or 1)
predicted_class = int(pred[0][0] > 0.5)  # Threshold at 0.5 for binary classification

# Step 4: Show the predicted class with its probability
print(f"Prediction: {labels[predicted_class]} with probability: {pred[0][0] * 100:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Prediction: Sensitive info shared without verification (Label 1) with probability: 100.00%

# %%
message = ['Hello this is Max from ABC credit bank. Am I talking to Adam? Yes you are. You son of bitch why did not you pay the last installment of your debt. I would like to talk for this matter professionally and respectfully. Okay Whats your Date of Birth and address for respecting your  privacy? its 14th January 1990 and I am living on Adam block, high rise apartment , new york. Thanks your due amount is 500$.']

# Step 1: Tokenize and pad the message
seq = tokenizer.texts_to_sequences(message)  # Convert text to sequence of integers
padded = pad_sequences(seq, maxlen=max_len, dtype='int32', value=0)  # Pad the sequence

# Step 2: Make a prediction with the model
pred = model.predict(padded)  # Get the prediction probability

# Define labels
labels = ['No issue (Label 0)', 'Sensitive info shared without verification (Label 1)']

# Get the predicted class (0 or 1)
predicted_class = int(pred[0][0] > 0.5)  # Threshold at 0.5 for binary classification

# Step 4: Show the predicted class with its probability
print(f"Prediction: {labels[predicted_class]} with probability: {pred[0][0] * 100:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Prediction: No issue (Label 0) with probability: 0.00%

# %%
message = ['Hello, this is Mark from XYZ Collections. How are you today? I am okay, thanks. What is this about? I am calling regarding your outstanding debt with Global Bank. Can you confirm your name for me? It is Jordan Smith. Thank you, Jordan. Your account shows a balance of $750. How would you like to settle this today? I need to check my finances before deciding. I understand. Just so you know, we can set up a payment plan if that helps. That could work. Can you send me the details? Absolutely, I can send that via email. Can you confirm your email address? It is jordan.smith@email.com. Great! I will send the details right away. Is there anything else you need? No, that is all for now. Thanks. You are welcome! Have a great day. You too. Bye!']

# Step 1: Tokenize and pad the message
seq = tokenizer.texts_to_sequences(message)  # Convert text to sequence of integers
padded = pad_sequences(seq, maxlen=max_len, dtype='int32', value=0)  # Pad the sequence

# Step 2: Make a prediction with the model
pred = model.predict(padded)  # Get the prediction probability

# Define labels
labels = ['No issue (Label 0)', 'Sensitive info shared without verification (Label 1)']

# Get the predicted class (0 or 1)
predicted_class = int(pred[0][0] > 0.5)  # Threshold at 0.5 for binary classification

# Step 4: Show the predicted class with its probability
print(f"Prediction: {labels[predicted_class]} with probability: {pred[0][0] * 100:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Prediction: No issue (Label 0) with probability: 0.00%
