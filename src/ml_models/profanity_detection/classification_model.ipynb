# %%
import pandas as pd
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Step 1: Load the Dataset
file_path = '/Users/mohammadadnaan/Downloads/Prodigal_Tech/intelligent-debt-recovery-genai/src/ml_models/profanity_detection/profanity_data.csv'
df = pd.read_csv(file_path)

# Display few rows
print(df.head())
print(df.tail())
# Out:
#                                                 text  label
# 0  hello this is emma from xyz collections how ar...      0
# 1  i am fine but i really do not have time for th...      0
# 2  i understand i will be brief i am calling abou...      0
# 3  look i have told you before i want my number o...      0
# 4  i apologize for that i will ensure your number...      0
#                                                    text  label
# 3182  time you think you can just sit on your ass an...      1
# 3183  i assure you that i am taking this seriously a...      0
# 3184  you better do it fast or i am going to escalat...      1
# 3185          i understand thank you for your call mike      0
# 3186  whatever just make sure you do not screw this ...      1

# %%
# Step 2: Preprocess the Text Data
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    
    # Remove special characters and numbers
    text = re.sub(r"[^a-zA-Z\s]", "", text)
    
    # Lemmatization (using simple rule-based approach)
    lemmatized_text = []
    for word in text.split():
        if word.endswith('ing'):
            word = word[:-3]  # Remove 'ing'
        elif word.endswith('ed'):
            word = word[:-2]  # Remove 'ed'
        elif word.endswith('s'):
            word = word[:-1]  # Remove 's'
        lemmatized_text.append(word)
    text = " ".join(lemmatized_text)
    
    # Remove stop words (using a custom list)
    stop_words = set(["the", "and", "is", "in", "it", "to", "of", "for", "with", "on", "at", "by", "this", "that", "are", "as", "be", "was", "were", "you", "your", "we", "our"])
    text = " ".join([word for word in text.split() if word not in stop_words])
    
    return text

# Apply preprocessing to the text column
df["Processed_Text"] = df["text"].apply(preprocess_text)

# %%
# Step 3: Convert Text to Numerical Features
vectorizer = TfidfVectorizer(max_features=5000)  # Limit vocabulary to 5000 words
X = vectorizer.fit_transform(df["Processed_Text"]).toarray()  # Convert text to TF-IDF features
y = df["label"]

# Save the TF-IDF vectorizer for future use
import pickle
with open('/Users/mohammadadnaan/Downloads/Prodigal_Tech/intelligent-debt-recovery-genai/src/ml_models/profanity_detection/tfidf_vectorizer.pkl', 'wb') as f:
    pickle.dump(vectorizer, f)

# %%
# Step 4: Handle Class Imbalance
# Use SMOTE to balance the dataset
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
# Step 5: Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# %%
# Step 6: Build the Model
model = Sequential([
    Dense(128, activation="relu", input_shape=(X_train.shape[1],), kernel_regularizer=l2(0.01)),  # Input layer
    Dropout(0.5),  # Add dropout to prevent overfitting
    Dense(64, activation="relu", kernel_regularizer=l2(0.01)),  # Hidden layer
    Dropout(0.5),  # Add dropout to prevent overfitting
    Dense(1, activation="sigmoid")  # Output layer for binary classification
])

# Compile the model
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])


# Display the model summary
model.summary()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │       119,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 127,361 (497.50 KB)
#  Trainable params: 127,361 (497.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Step 7: Train the Model with Early Stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7378 - loss: 2.1855 - val_accuracy: 0.9665 - val_loss: 0.4804
# Epoch 2/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9620 - loss: 0.4248 - val_accuracy: 0.9717 - val_loss: 0.3129
# Epoch 3/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9738 - loss: 0.3016 - val_accuracy: 0.9780 - val_loss: 0.2749
# Epoch 4/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - accuracy: 0.9727 - loss: 0.2784 - val_accuracy: 0.9822 - val_loss: 0.2536
# Epoch 5/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - accuracy: 0.9830 - loss: 0.2466 - val_accuracy: 0.9811 - val_loss: 0.2479
# Epoch 6/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - accuracy: 0.9797 - loss: 0.2451 - val_accuracy: 0.9801 - val_loss: 0.2330
# Epoch 7/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - accuracy: 0.9835 - loss: 0.2262 - val_accuracy: 0.9906 - val_loss: 0.2172
# Epoch 8/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - accuracy: 0.9804 - loss: 0.2250 - val_accuracy: 0.9832 - val_loss: 0.2181
# Epoch 9/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - accuracy: 0.9852 - loss: 0.2112 - val_accuracy: 0.9811 - val_loss: 0.2078
# Epoch 10/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - accuracy: 0.9862 - loss: 0.1998 - val_accuracy: 0.9874 - val_loss: 0.2079
# Epoch 11/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - accuracy: 0.9837 - loss: 0.2025 - val_accuracy: 0.9843 - val_loss: 0.2041
# Epoch 12/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - accuracy: 0.9837 - loss: 0.2003 - val_accuracy: 0.9864 - val_loss: 0.1946
# Epoch 13/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - accuracy: 0.9884 - loss: 0.1887 - val_accuracy: 0.9864 - val_loss: 0.1931
# Epoch 14/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - accuracy: 0.9826 - loss: 0.1963 - val_accuracy: 0.9874 - val_loss: 0.1868
# Epoch 15/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - accuracy: 0.9868 - loss: 0.1833 - val_accuracy: 0.9895 - val_loss: 0.1841
# Epoch 16/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - accuracy: 0.9836 - loss: 0.1852 - val_accuracy: 0.9864 - val_loss: 0.1810
# Epoch 17/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - accuracy: 0.9882 - loss: 0.1763 - val_accuracy: 0.9874 - val_loss: 0.1776
# Epoch 18/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - accuracy: 0.9875 - loss: 0.1713 - val_accuracy: 0.9853 - val_loss: 0.1769
# Epoch 19/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - accuracy: 0.9866 - loss: 0.1783 - val_accuracy: 0.9864 - val_loss: 0.1683
# Epoch 20/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - accuracy: 0.9881 - loss: 0.1653 - val_accuracy: 0.9885 - val_loss: 0.1648
# Epoch 21/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - accuracy: 0.9869 - loss: 0.1698 - val_accuracy: 0.9790 - val_loss: 0.1747
# Epoch 22/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - accuracy: 0.9872 - loss: 0.1699 - val_accuracy: 0.9916 - val_loss: 0.1652
# Epoch 23/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - accuracy: 0.9903 - loss: 0.1626 - val_accuracy: 0.9906 - val_loss: 0.1603
# Epoch 24/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - accuracy: 0.9904 - loss: 0.1597 - val_accuracy: 0.9853 - val_loss: 0.1642
# Epoch 25/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - accuracy: 0.9921 - loss: 0.1529 - val_accuracy: 0.9927 - val_loss: 0.1564
# Epoch 26/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - accuracy: 0.9924 - loss: 0.1510 - val_accuracy: 0.9916 - val_loss: 0.1566
# Epoch 27/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - accuracy: 0.9878 - loss: 0.1533 - val_accuracy: 0.9895 - val_loss: 0.1571
# Epoch 28/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - accuracy: 0.9886 - loss: 0.1555 - val_accuracy: 0.9864 - val_loss: 0.1624
# Epoch 29/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - accuracy: 0.9899 - loss: 0.1593 - val_accuracy: 0.9853 - val_loss: 0.1603
# Epoch 30/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - accuracy: 0.9900 - loss: 0.1501 - val_accuracy: 0.9895 - val_loss: 0.1535
# Epoch 31/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - accuracy: 0.9897 - loss: 0.1464 - val_accuracy: 0.9874 - val_loss: 0.1557
# Epoch 32/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - accuracy: 0.9914 - loss: 0.1444 - val_accuracy: 0.9895 - val_loss: 0.1519
# Epoch 33/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - accuracy: 0.9903 - loss: 0.1464 - val_accuracy: 0.9895 - val_loss: 0.1525
# Epoch 34/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - accuracy: 0.9944 - loss: 0.1367 - val_accuracy: 0.9906 - val_loss: 0.1501
# Epoch 35/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - accuracy: 0.9912 - loss: 0.1462 - val_accuracy: 0.9895 - val_loss: 0.1466
# Epoch 36/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - accuracy: 0.9911 - loss: 0.1414 - val_accuracy: 0.9916 - val_loss: 0.1394
# Epoch 37/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - accuracy: 0.9881 - loss: 0.1479 - val_accuracy: 0.9874 - val_loss: 0.1454
# Epoch 38/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.9933 - loss: 0.1339 - val_accuracy: 0.9895 - val_loss: 0.1475
# Epoch 39/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - accuracy: 0.9930 - loss: 0.1324 - val_accuracy: 0.9895 - val_loss: 0.1303
# Epoch 40/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - accuracy: 0.9906 - loss: 0.1324 - val_accuracy: 0.9885 - val_loss: 0.1474
# Epoch 41/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - accuracy: 0.9916 - loss: 0.1404 - val_accuracy: 0.9927 - val_loss: 0.1383
# Epoch 42/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - accuracy: 0.9894 - loss: 0.1397 - val_accuracy: 0.9906 - val_loss: 0.1412
# Epoch 43/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - accuracy: 0.9914 - loss: 0.1394 - val_accuracy: 0.9895 - val_loss: 0.1379
# Epoch 44/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9940 - loss: 0.1255 - val_accuracy: 0.9906 - val_loss: 0.1330
# Epoch 45/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9900 - loss: 0.1298 - val_accuracy: 0.9916 - val_loss: 0.1380
# Epoch 46/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9919 - loss: 0.1264 - val_accuracy: 0.9895 - val_loss: 0.1381
# Epoch 47/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9925 - loss: 0.1287 - val_accuracy: 0.9874 - val_loss: 0.1383
# Epoch 48/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9925 - loss: 0.1260 - val_accuracy: 0.9874 - val_loss: 0.1344
# Epoch 49/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9922 - loss: 0.1214 - val_accuracy: 0.9895 - val_loss: 0.1363
# Epoch 50/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9947 - loss: 0.1170 - val_accuracy: 0.9874 - val_loss: 0.1371
# Epoch 51/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9892 - loss: 0.1261 - val_accuracy: 0.9906 - val_loss: 0.1259
# Epoch 52/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9930 - loss: 0.1209 - val_accuracy: 0.9906 - val_loss: 0.1336
# Epoch 53/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9938 - loss: 0.1254 - val_accuracy: 0.9906 - val_loss: 0.1330
# Epoch 54/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9934 - loss: 0.1232 - val_accuracy: 0.9937 - val_loss: 0.1235
# Epoch 55/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9946 - loss: 0.1141 - val_accuracy: 0.9906 - val_loss: 0.1228
# Epoch 56/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9915 - loss: 0.1214 - val_accuracy: 0.9927 - val_loss: 0.1260
# Epoch 57/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9917 - loss: 0.1184 - val_accuracy: 0.9906 - val_loss: 0.1228
# Epoch 58/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9928 - loss: 0.1224 - val_accuracy: 0.9927 - val_loss: 0.1262
# Epoch 59/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9912 - loss: 0.1240 - val_accuracy: 0.9906 - val_loss: 0.1318
# Epoch 60/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9906 - loss: 0.1190 - val_accuracy: 0.9937 - val_loss: 0.1217
# Epoch 61/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9867 - loss: 0.1236 - val_accuracy: 0.9906 - val_loss: 0.1224
# Epoch 62/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9899 - loss: 0.1143 - val_accuracy: 0.9906 - val_loss: 0.1282
# Epoch 63/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9928 - loss: 0.1126 - val_accuracy: 0.9895 - val_loss: 0.1276
# Epoch 64/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9930 - loss: 0.1124 - val_accuracy: 0.9937 - val_loss: 0.1156
# Epoch 65/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9946 - loss: 0.1116 - val_accuracy: 0.9885 - val_loss: 0.1362
# Epoch 66/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9919 - loss: 0.1146 - val_accuracy: 0.9895 - val_loss: 0.1189
# Epoch 67/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9931 - loss: 0.1103 - val_accuracy: 0.9906 - val_loss: 0.1197
# Epoch 68/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9952 - loss: 0.1094 - val_accuracy: 0.9916 - val_loss: 0.1154
# Epoch 69/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9934 - loss: 0.1090 - val_accuracy: 0.9927 - val_loss: 0.1189
# Epoch 70/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9930 - loss: 0.1138 - val_accuracy: 0.9927 - val_loss: 0.1194
# Epoch 71/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9941 - loss: 0.1063 - val_accuracy: 0.9906 - val_loss: 0.1197
# Epoch 72/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9908 - loss: 0.1188 - val_accuracy: 0.9937 - val_loss: 0.1151
# Epoch 73/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9962 - loss: 0.1045 - val_accuracy: 0.9927 - val_loss: 0.1132
# Epoch 74/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9898 - loss: 0.1075 - val_accuracy: 0.9906 - val_loss: 0.1183
# Epoch 75/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9942 - loss: 0.1029 - val_accuracy: 0.9906 - val_loss: 0.1170
# Epoch 76/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9915 - loss: 0.1080 - val_accuracy: 0.9937 - val_loss: 0.1121
# Epoch 77/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9935 - loss: 0.1083 - val_accuracy: 0.9916 - val_loss: 0.1162
# Epoch 78/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9948 - loss: 0.1020 - val_accuracy: 0.9927 - val_loss: 0.1179
# Epoch 79/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9942 - loss: 0.1076 - val_accuracy: 0.9916 - val_loss: 0.1179
# Epoch 80/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9912 - loss: 0.1110 - val_accuracy: 0.9927 - val_loss: 0.1124
# Epoch 81/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9958 - loss: 0.0987 - val_accuracy: 0.9843 - val_loss: 0.1279
# Epoch 82/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9957 - loss: 0.1049 - val_accuracy: 0.9906 - val_loss: 0.1122
# Epoch 83/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9934 - loss: 0.1051 - val_accuracy: 0.9916 - val_loss: 0.1136
# Epoch 84/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9928 - loss: 0.1192 - val_accuracy: 0.9916 - val_loss: 0.1142
# Epoch 85/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9911 - loss: 0.1103 - val_accuracy: 0.9927 - val_loss: 0.1160
# Epoch 86/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - accuracy: 0.9936 - loss: 0.0996 - val_accuracy: 0.9927 - val_loss: 0.1132
# Epoch 87/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9920 - loss: 0.1011 - val_accuracy: 0.9864 - val_loss: 0.1150
# Epoch 88/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9948 - loss: 0.0973 - val_accuracy: 0.9927 - val_loss: 0.1072
# Epoch 89/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - accuracy: 0.9932 - loss: 0.0975 - val_accuracy: 0.9906 - val_loss: 0.1127
# Epoch 90/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9944 - loss: 0.0996 - val_accuracy: 0.9927 - val_loss: 0.1107
# Epoch 91/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9941 - loss: 0.1058 - val_accuracy: 0.9895 - val_loss: 0.1163
# Epoch 92/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9940 - loss: 0.0986 - val_accuracy: 0.9916 - val_loss: 0.1067
# Epoch 93/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9938 - loss: 0.0937 - val_accuracy: 0.9906 - val_loss: 0.1148
# Epoch 94/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9922 - loss: 0.1036 - val_accuracy: 0.9937 - val_loss: 0.1124
# Epoch 95/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9934 - loss: 0.1070 - val_accuracy: 0.9937 - val_loss: 0.1085
# Epoch 96/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9948 - loss: 0.1005 - val_accuracy: 0.9927 - val_loss: 0.1076
# Epoch 97/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9944 - loss: 0.0924 - val_accuracy: 0.9937 - val_loss: 0.1034
# Epoch 98/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9959 - loss: 0.0927 - val_accuracy: 0.9927 - val_loss: 0.1058
# Epoch 99/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9945 - loss: 0.0936 - val_accuracy: 0.9916 - val_loss: 0.1098
# Epoch 100/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9936 - loss: 0.1009 - val_accuracy: 0.9916 - val_loss: 0.1041
# Epoch 101/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9948 - loss: 0.0967 - val_accuracy: 0.9916 - val_loss: 0.1032
# Epoch 102/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9915 - loss: 0.0991 - val_accuracy: 0.9927 - val_loss: 0.1065
# Epoch 103/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9962 - loss: 0.0910 - val_accuracy: 0.9906 - val_loss: 0.1130
# Epoch 104/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9915 - loss: 0.1111 - val_accuracy: 0.9906 - val_loss: 0.1109
# Epoch 105/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9917 - loss: 0.1025 - val_accuracy: 0.9906 - val_loss: 0.1112
# Epoch 106/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9916 - loss: 0.1033 - val_accuracy: 0.9927 - val_loss: 0.1071
# Epoch 107/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9944 - loss: 0.0975 - val_accuracy: 0.9927 - val_loss: 0.1041
# Epoch 108/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9942 - loss: 0.0913 - val_accuracy: 0.9916 - val_loss: 0.1098
# Epoch 109/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9966 - loss: 0.0886 - val_accuracy: 0.9895 - val_loss: 0.1011
# Epoch 110/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9952 - loss: 0.0879 - val_accuracy: 0.9937 - val_loss: 0.0993
# Epoch 111/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9916 - loss: 0.0994 - val_accuracy: 0.9906 - val_loss: 0.1006
# Epoch 112/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9953 - loss: 0.0855 - val_accuracy: 0.9927 - val_loss: 0.1063
# Epoch 113/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9955 - loss: 0.0901 - val_accuracy: 0.9906 - val_loss: 0.1082
# Epoch 114/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9937 - loss: 0.0890 - val_accuracy: 0.9916 - val_loss: 0.0984
# Epoch 115/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9950 - loss: 0.0841 - val_accuracy: 0.9874 - val_loss: 0.1075
# Epoch 116/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9907 - loss: 0.0993 - val_accuracy: 0.9927 - val_loss: 0.0997
# Epoch 117/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9946 - loss: 0.0906 - val_accuracy: 0.9927 - val_loss: 0.0973
# Epoch 118/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9974 - loss: 0.0846 - val_accuracy: 0.9927 - val_loss: 0.0997
# Epoch 119/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9940 - loss: 0.0848 - val_accuracy: 0.9906 - val_loss: 0.0989
# Epoch 120/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9953 - loss: 0.0882 - val_accuracy: 0.9927 - val_loss: 0.0984
# Epoch 121/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9936 - loss: 0.0903 - val_accuracy: 0.9916 - val_loss: 0.1048
# Epoch 122/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9942 - loss: 0.0914 - val_accuracy: 0.9916 - val_loss: 0.1033
# Epoch 123/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9906 - loss: 0.0899 - val_accuracy: 0.9916 - val_loss: 0.0991
# Epoch 124/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9926 - loss: 0.0819 - val_accuracy: 0.9885 - val_loss: 0.1067
# Epoch 125/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9940 - loss: 0.0927 - val_accuracy: 0.9937 - val_loss: 0.0978
# Epoch 126/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9967 - loss: 0.0828 - val_accuracy: 0.9906 - val_loss: 0.0988
# Epoch 127/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9939 - loss: 0.0899 - val_accuracy: 0.9937 - val_loss: 0.0959
# Epoch 128/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9953 - loss: 0.0841 - val_accuracy: 0.9895 - val_loss: 0.0979
# Epoch 129/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9919 - loss: 0.0933 - val_accuracy: 0.9916 - val_loss: 0.1002
# Epoch 130/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9956 - loss: 0.0849 - val_accuracy: 0.9927 - val_loss: 0.0964
# Epoch 131/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9946 - loss: 0.0854 - val_accuracy: 0.9937 - val_loss: 0.0975
# Epoch 132/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9951 - loss: 0.0838 - val_accuracy: 0.9937 - val_loss: 0.1022
# Epoch 133/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9923 - loss: 0.0926 - val_accuracy: 0.9927 - val_loss: 0.0978
# Epoch 134/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - accuracy: 0.9960 - loss: 0.0832 - val_accuracy: 0.9916 - val_loss: 0.1033
# Epoch 135/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9950 - loss: 0.0836 - val_accuracy: 0.9853 - val_loss: 0.1150
# Epoch 136/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9935 - loss: 0.0924 - val_accuracy: 0.9916 - val_loss: 0.0986
# Epoch 137/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9945 - loss: 0.0849 - val_accuracy: 0.9916 - val_loss: 0.0990
# Epoch 138/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9902 - loss: 0.0959 - val_accuracy: 0.9937 - val_loss: 0.1024
# Epoch 139/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.1020 - val_accuracy: 0.9927 - val_loss: 0.0962
# Epoch 140/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9959 - loss: 0.0789 - val_accuracy: 0.9927 - val_loss: 0.0969
# Epoch 141/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9956 - loss: 0.0822 - val_accuracy: 0.9937 - val_loss: 0.0965
# Epoch 142/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9944 - loss: 0.0856 - val_accuracy: 0.9927 - val_loss: 0.0928
# Epoch 143/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9953 - loss: 0.0794 - val_accuracy: 0.9927 - val_loss: 0.0946
# Epoch 144/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9916 - loss: 0.0861 - val_accuracy: 0.9916 - val_loss: 0.1027
# Epoch 145/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9946 - loss: 0.0842 - val_accuracy: 0.9895 - val_loss: 0.0972
# Epoch 146/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9942 - loss: 0.0807 - val_accuracy: 0.9906 - val_loss: 0.0899
# Epoch 147/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9967 - loss: 0.0766 - val_accuracy: 0.9937 - val_loss: 0.0955
# Epoch 148/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9938 - loss: 0.0832 - val_accuracy: 0.9937 - val_loss: 0.0979
# Epoch 149/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - accuracy: 0.9966 - loss: 0.0809 - val_accuracy: 0.9937 - val_loss: 0.0977
# Epoch 150/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9967 - loss: 0.0793 - val_accuracy: 0.9927 - val_loss: 0.0947
# Epoch 151/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9942 - loss: 0.0850 - val_accuracy: 0.9937 - val_loss: 0.0965
# Epoch 152/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9944 - loss: 0.0889 - val_accuracy: 0.9937 - val_loss: 0.0963
# Epoch 153/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9964 - loss: 0.0824 - val_accuracy: 0.9927 - val_loss: 0.0880
# Epoch 154/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9962 - loss: 0.0744 - val_accuracy: 0.9895 - val_loss: 0.0940
# Epoch 155/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9935 - loss: 0.0796 - val_accuracy: 0.9927 - val_loss: 0.0885
# Epoch 156/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9956 - loss: 0.0765 - val_accuracy: 0.9916 - val_loss: 0.0925
# Epoch 157/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9954 - loss: 0.0749 - val_accuracy: 0.9895 - val_loss: 0.0946
# Epoch 158/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9919 - loss: 0.0830 - val_accuracy: 0.9927 - val_loss: 0.0899
# Epoch 159/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9963 - loss: 0.0775 - val_accuracy: 0.9927 - val_loss: 0.0903
# Epoch 160/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9934 - loss: 0.0796 - val_accuracy: 0.9895 - val_loss: 0.1004
# Epoch 161/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9908 - loss: 0.0944 - val_accuracy: 0.9927 - val_loss: 0.0980
# Epoch 162/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9944 - loss: 0.0871 - val_accuracy: 0.9906 - val_loss: 0.0972
# Epoch 163/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9932 - loss: 0.0852 - val_accuracy: 0.9916 - val_loss: 0.1005
# Epoch 164/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9961 - loss: 0.0806 - val_accuracy: 0.9916 - val_loss: 0.0883
# Epoch 165/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9921 - loss: 0.0834 - val_accuracy: 0.9916 - val_loss: 0.0967
# Epoch 166/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - accuracy: 0.9946 - loss: 0.0772 - val_accuracy: 0.9916 - val_loss: 0.0925
# Epoch 167/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9939 - loss: 0.0763 - val_accuracy: 0.9906 - val_loss: 0.0937
# Epoch 168/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9959 - loss: 0.0783 - val_accuracy: 0.9937 - val_loss: 0.0858
# Epoch 169/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9953 - loss: 0.0766 - val_accuracy: 0.9916 - val_loss: 0.0908
# Epoch 170/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9923 - loss: 0.0867 - val_accuracy: 0.9916 - val_loss: 0.0958
# Epoch 171/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9951 - loss: 0.0826 - val_accuracy: 0.9895 - val_loss: 0.0979
# Epoch 172/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9941 - loss: 0.0818 - val_accuracy: 0.9937 - val_loss: 0.0856
# Epoch 173/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9959 - loss: 0.0743 - val_accuracy: 0.9906 - val_loss: 0.0902
# Epoch 174/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9951 - loss: 0.0787 - val_accuracy: 0.9927 - val_loss: 0.0950
# Epoch 175/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9958 - loss: 0.0764 - val_accuracy: 0.9916 - val_loss: 0.0939
# Epoch 176/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9956 - loss: 0.0757 - val_accuracy: 0.9937 - val_loss: 0.0890
# Epoch 177/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9957 - loss: 0.0769 - val_accuracy: 0.9937 - val_loss: 0.0898
# Epoch 178/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9941 - loss: 0.0818 - val_accuracy: 0.9948 - val_loss: 0.0858
# Epoch 179/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9957 - loss: 0.0772 - val_accuracy: 0.9916 - val_loss: 0.0888
# Epoch 180/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9941 - loss: 0.0842 - val_accuracy: 0.9927 - val_loss: 0.0882
# Epoch 181/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9944 - loss: 0.0744 - val_accuracy: 0.9937 - val_loss: 0.0922
# Epoch 182/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9929 - loss: 0.0840 - val_accuracy: 0.9916 - val_loss: 0.0907
# Epoch 183/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9935 - loss: 0.0759 - val_accuracy: 0.9885 - val_loss: 0.1015
# Epoch 184/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9933 - loss: 0.0842 - val_accuracy: 0.9906 - val_loss: 0.0986
# Epoch 185/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - accuracy: 0.9960 - loss: 0.0766 - val_accuracy: 0.9937 - val_loss: 0.0906
# Epoch 186/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9969 - loss: 0.0758 - val_accuracy: 0.9885 - val_loss: 0.0904
# Epoch 187/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9930 - loss: 0.0764 - val_accuracy: 0.9937 - val_loss: 0.0943
# Epoch 188/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9961 - loss: 0.0751 - val_accuracy: 0.9927 - val_loss: 0.0884
# Epoch 189/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9951 - loss: 0.0726 - val_accuracy: 0.9853 - val_loss: 0.1081
# Epoch 190/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9947 - loss: 0.0791 - val_accuracy: 0.9927 - val_loss: 0.0853
# Epoch 191/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9943 - loss: 0.0734 - val_accuracy: 0.9927 - val_loss: 0.0883
# Epoch 192/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9955 - loss: 0.0769 - val_accuracy: 0.9906 - val_loss: 0.0924
# Epoch 193/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9957 - loss: 0.0746 - val_accuracy: 0.9927 - val_loss: 0.0862
# Epoch 194/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9934 - loss: 0.0728 - val_accuracy: 0.9937 - val_loss: 0.0829
# Epoch 195/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9949 - loss: 0.0710 - val_accuracy: 0.9895 - val_loss: 0.0938
# Epoch 196/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9939 - loss: 0.0790 - val_accuracy: 0.9937 - val_loss: 0.0867
# Epoch 197/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - accuracy: 0.9932 - loss: 0.0766 - val_accuracy: 0.9906 - val_loss: 0.0955
# Epoch 198/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - accuracy: 0.9947 - loss: 0.0736 - val_accuracy: 0.9948 - val_loss: 0.0866
# Epoch 199/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - accuracy: 0.9953 - loss: 0.0689 - val_accuracy: 0.9906 - val_loss: 0.0884
# Epoch 200/200
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9951 - loss: 0.0734 - val_accuracy: 0.9927 - val_loss: 0.0884

# %%
# Step 8: Evaluate the Model
# Predict on the test set
y_pred = (model.predict(X_test) > 0.5).astype("int32")

# Print classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Print accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       614
#            1       0.99      1.00      1.00       579
#
#     accuracy                           1.00      1193
#    macro avg       1.00      1.00      1.00      1193
# weighted avg       1.00      1.00      1.00      1193
#
# Accuracy: 99.66%

# %%
# Print accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 99.66%

# %%
def predict_profanity(text):
    # Step 1: Preprocess the input text
    processed_text = preprocess_text(text)
    
    # Step 2: Convert the preprocessed text to numerical features using the same vectorizer
    text_vectorized = vectorizer.transform([processed_text]).toarray()
    
    # Step 3: Make a prediction using the trained model
    pred = model.predict(text_vectorized)
    
    # Step 4: Interpret the prediction
    label = "profane" if pred[0][0] > 0.5 else "not profane"
    probability = pred[0][0] * 100 if label == "profane" else (1 - pred[0][0]) * 100
    
    # Step 5: Print the result
    print(f"Text: {text}")
    print(f"Prediction: {label} with probability: {probability:.2f}%")
    print()

# Test examples
predict_profanity("Your account has been flagged for suspicious activity. Please call us immediately to resolve the issue.")
predict_profanity("Fuck you! Go to hell!")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Text: Your account has been flagged for suspicious activity. Please call us immediately to resolve the issue.
# Prediction: not profane with probability: 99.69%
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Text: Fuck you! Go to hell!
# Prediction: profane with probability: 99.75%

# %%
# Save the model after evaluation
model.save('profanity.keras')
